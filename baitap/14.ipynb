# %%
import numpy as np
from PIL import Image

def average_images(image_list):
    total_array = np.array(Image.open(image_list[0]), 'f')
    count=1

    for image_path in image_list[1:]:
        try:
            image_array = np.array(Image.open(image_path), 'f')
            total_array += image_array
            count=count+1
        except:
            print("Skip ", image_path);

    # Tính trung bình
    average_array = total_array / count

    # Chuyển đổi kết quả trung bình thành hình ảnh
    average_image = Image.fromarray(average_array.astype('uint8'))

    return average_image

# Sử dụng ví dụ:
my_path_1 = 'D:/JS Duy/DNTU/nam4/ki1/thigiacmaytinh/img/01/1.jpg'
my_path_2 = 'D:/JS Duy/DNTU/nam4/ki1/thigiacmaytinh/img/01/2.jpg'
image_list = [my_path_1, my_path_2]
result_image = average_images(image_list)
display(result_image)


# Sử dụng ví dụ:
my_path_1 = 'D:/JS Duy/DNTU/nam4/ki1/thigiacmaytinh/img/01/3.jpg'
my_path_2 = 'D:/JS Duy/DNTU/nam4/ki1/thigiacmaytinh/img/01/4.jpg'
image_list = [my_path_1, my_path_2]
result_image = average_images(image_list)
display(result_image)
# Out:
# <PIL.Image.Image image mode=RGB size=397x397>
# <PIL.Image.Image image mode=RGB size=1344x768>
